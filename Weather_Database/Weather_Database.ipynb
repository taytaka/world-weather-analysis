# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %%
# Perform an API call with the OpenWeatherMap.
import requests
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call: Latitude and longitude, Maximum temperature, 
# Percent humidity, Percent cloudiness, Wind speed, Weather description (for example, clouds, fog, light rain, clear sky)
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current,
                          "Country": city_country,})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | jacareacanga
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | jawhar
# Processing Record 5 of Set 1 | ribas do rio pardo
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | bathsheba
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | port hardy
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | coquimbo
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | bagaha
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | ucluelet
# Processing Record 28 of Set 1 | serta
# Processing Record 29 of Set 1 | yauya
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | zhigalovo
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | pteleos
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | kerouane
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | hammerfest
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | leningradskiy
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | tombouctou
# Processing Record 47 of Set 1 | roald
# Processing Record 48 of Set 1 | borova
# Processing Record 49 of Set 1 | clyde river
# Processing Record 50 of Set 1 | piranshahr
# Processing Record 1 of Set 2 | mount isa
# Processing Record 2 of Set 2 | ahipara
# Processing Record 3 of Set 2 | kaitangata
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | nantucket
# Processing Record 6 of Set 2 | zhireken
# Processing Record 7 of Set 2 | ola
# Processing Record 8 of Set 2 | pringsewu
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | adeje
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | qasigiannguit
# Processing Record 14 of Set 2 | visnes
# Processing Record 15 of Set 2 | labuhan
# Processing Record 16 of Set 2 | semnan
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | sovetskiy
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | lorengau
# Processing Record 23 of Set 2 | puerto colombia
# Processing Record 24 of Set 2 | taybad
# Processing Record 25 of Set 2 | teguise
# Processing Record 26 of Set 2 | kavaratti
# Processing Record 27 of Set 2 | beringovskiy
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | dzaoudzi
# Processing Record 31 of Set 2 | boffa
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | rocha
# Processing Record 34 of Set 2 | balkanabat
# Processing Record 35 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 2 | bonthe
# Processing Record 37 of Set 2 | hamilton
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | jizan
# Processing Record 40 of Set 2 | mareeba
# Processing Record 41 of Set 2 | te anau
# Processing Record 42 of Set 2 | nago
# Processing Record 43 of Set 2 | lompoc
# Processing Record 44 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 2 | brownfield
# Processing Record 47 of Set 2 | broome
# Processing Record 48 of Set 2 | eirunepe
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | bang saphan
# Processing Record 1 of Set 3 | agua branca
# Processing Record 2 of Set 3 | khanpur
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | goderich
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | pevek
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | sao tome
# Processing Record 9 of Set 3 | asahikawa
# Processing Record 10 of Set 3 | nova olimpia
# Processing Record 11 of Set 3 | sur
# Processing Record 12 of Set 3 | nome
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | esperance
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | harnosand
# Processing Record 18 of Set 3 | port lincoln
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | suwalki
# Processing Record 22 of Set 3 | develi
# Processing Record 23 of Set 3 | gamba
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | hami
# Processing Record 26 of Set 3 | maniitsoq
# Processing Record 27 of Set 3 | vardo
# Processing Record 28 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | havre-saint-pierre
# Processing Record 31 of Set 3 | dunedin
# Processing Record 32 of Set 3 | zhangye
# Processing Record 33 of Set 3 | saint-pierre
# Processing Record 34 of Set 3 | lethem
# Processing Record 35 of Set 3 | chapais
# Processing Record 36 of Set 3 | ozuluama
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | ohara
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | tyrma
# Processing Record 41 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 3 | thompson
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | quatre cocos
# Processing Record 46 of Set 3 | padang
# Processing Record 47 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 3 | chicama
# Processing Record 49 of Set 3 | sangar
# Processing Record 50 of Set 3 | kushima
# Processing Record 1 of Set 4 | stornoway
# Processing Record 2 of Set 4 | manta
# Processing Record 3 of Set 4 | alpine
# Processing Record 4 of Set 4 | durant
# Processing Record 5 of Set 4 | gizo
# Processing Record 6 of Set 4 | vuktyl
# Processing Record 7 of Set 4 | taborfalva
# Processing Record 8 of Set 4 | badaojiang
# City not found. Skipping...
# Processing Record 9 of Set 4 | gambela
# Processing Record 10 of Set 4 | zabaykalsk
# Processing Record 11 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 4 | pryazha
# Processing Record 14 of Set 4 | bethel
# Processing Record 15 of Set 4 | igualada
# Processing Record 16 of Set 4 | chokwe
# Processing Record 17 of Set 4 | aksha
# Processing Record 18 of Set 4 | dakar
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | santa barbara
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | half moon bay
# Processing Record 23 of Set 4 | springbok
# Processing Record 24 of Set 4 | belaya gora
# Processing Record 25 of Set 4 | saint-joseph
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | kaoma
# Processing Record 28 of Set 4 | renqiu
# Processing Record 29 of Set 4 | inirida
# Processing Record 30 of Set 4 | la ronge
# Processing Record 31 of Set 4 | ternate
# Processing Record 32 of Set 4 | namatanai
# Processing Record 33 of Set 4 | oban
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | lossiemouth
# Processing Record 37 of Set 4 | hadimkoy
# City not found. Skipping...
# Processing Record 38 of Set 4 | touros
# Processing Record 39 of Set 4 | gonen
# Processing Record 40 of Set 4 | lima
# Processing Record 41 of Set 4 | makubetsu
# Processing Record 42 of Set 4 | bantry
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | severo-kurilsk
# Processing Record 45 of Set 4 | ayagoz
# Processing Record 46 of Set 4 | bluff
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | upernavik
# Processing Record 49 of Set 4 | guatire
# Processing Record 50 of Set 4 | billings
# Processing Record 1 of Set 5 | amga
# Processing Record 2 of Set 5 | arroyo
# Processing Record 3 of Set 5 | kolaras
# Processing Record 4 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 5 | luang prabang
# Processing Record 6 of Set 5 | east london
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | sept-iles
# Processing Record 9 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 5 | tete
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | palu
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 5 | vrangel
# Processing Record 18 of Set 5 | kununurra
# Processing Record 19 of Set 5 | hambantota
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | halifax
# Processing Record 22 of Set 5 | langfang
# Processing Record 23 of Set 5 | norman wells
# Processing Record 24 of Set 5 | buraydah
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | ust-kuyga
# Processing Record 27 of Set 5 | ulsteinvik
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | skreia
# Processing Record 30 of Set 5 | kortkeros
# Processing Record 31 of Set 5 | iqaluit
# Processing Record 32 of Set 5 | takhatgarh
# Processing Record 33 of Set 5 | faya
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | atambua
# Processing Record 36 of Set 5 | trairi
# Processing Record 37 of Set 5 | ca mau
# Processing Record 38 of Set 5 | zadar
# Processing Record 39 of Set 5 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 5 | oistins
# Processing Record 41 of Set 5 | karakol
# Processing Record 42 of Set 5 | knysna
# Processing Record 43 of Set 5 | liverpool
# Processing Record 44 of Set 5 | srednekolymsk
# Processing Record 45 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 5 | dzhebariki-khaya
# Processing Record 47 of Set 5 | gannan
# Processing Record 48 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | acapulco
# Processing Record 1 of Set 6 | pauini
# Processing Record 2 of Set 6 | kulhudhuffushi
# Processing Record 3 of Set 6 | urumqi
# Processing Record 4 of Set 6 | walvis bay
# Processing Record 5 of Set 6 | baykit
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | san patricio
# Processing Record 8 of Set 6 | xunchang
# Processing Record 9 of Set 6 | puerto ayacucho
# Processing Record 10 of Set 6 | nadrag
# Processing Record 11 of Set 6 | togur
# Processing Record 12 of Set 6 | poronaysk
# Processing Record 13 of Set 6 | xapuri
# Processing Record 14 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 6 | argelia
# Processing Record 16 of Set 6 | moose factory
# Processing Record 17 of Set 6 | atbasar
# Processing Record 18 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 6 | la sarre
# Processing Record 20 of Set 6 | north platte
# Processing Record 21 of Set 6 | milingimbi
# City not found. Skipping...
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | laguna
# Processing Record 24 of Set 6 | ribeira brava
# Processing Record 25 of Set 6 | berekum
# Processing Record 26 of Set 6 | victoria
# Processing Record 27 of Set 6 | upata
# Processing Record 28 of Set 6 | nemuro
# Processing Record 29 of Set 6 | kwale
# Processing Record 30 of Set 6 | aykhal
# Processing Record 31 of Set 6 | emerald
# Processing Record 32 of Set 6 | fortuna
# Processing Record 33 of Set 6 | xining
# Processing Record 34 of Set 6 | cajazeiras
# Processing Record 35 of Set 6 | lagoa
# Processing Record 36 of Set 6 | talnakh
# Processing Record 37 of Set 6 | itabuna
# Processing Record 38 of Set 6 | pizhma
# Processing Record 39 of Set 6 | yashkul
# Processing Record 40 of Set 6 | arrecife
# Processing Record 41 of Set 6 | mar del plata
# Processing Record 42 of Set 6 | tuktoyaktuk
# Processing Record 43 of Set 6 | avera
# Processing Record 44 of Set 6 | dryden
# Processing Record 45 of Set 6 | san andres
# Processing Record 46 of Set 6 | sal rei
# Processing Record 47 of Set 6 | torbay
# Processing Record 48 of Set 6 | ambilobe
# Processing Record 49 of Set 6 | kolimvari
# City not found. Skipping...
# Processing Record 50 of Set 6 | byron bay
# Processing Record 1 of Set 7 | yellowknife
# Processing Record 2 of Set 7 | nanortalik
# Processing Record 3 of Set 7 | namibe
# Processing Record 4 of Set 7 | zhigansk
# Processing Record 5 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 7 | ishigaki
# Processing Record 7 of Set 7 | zyryanka
# Processing Record 8 of Set 7 | nicoya
# Processing Record 9 of Set 7 | arraial do cabo
# Processing Record 10 of Set 7 | khipro
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | abnub
# Processing Record 13 of Set 7 | khatanga
# Processing Record 14 of Set 7 | aklavik
# Processing Record 15 of Set 7 | kapit
# Processing Record 16 of Set 7 | mahajanga
# Processing Record 17 of Set 7 | asau
# Processing Record 18 of Set 7 | hay river
# Processing Record 19 of Set 7 | brooks
# Processing Record 20 of Set 7 | gobabis
# Processing Record 21 of Set 7 | cherskiy
# Processing Record 22 of Set 7 | langwedel
# Processing Record 23 of Set 7 | lodwar
# Processing Record 24 of Set 7 | harper
# Processing Record 25 of Set 7 | bereda
# Processing Record 26 of Set 7 | belmonte
# Processing Record 27 of Set 7 | nosy varika
# Processing Record 28 of Set 7 | jalu
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | yabassi
# Processing Record 31 of Set 7 | le mars
# Processing Record 32 of Set 7 | muros
# Processing Record 33 of Set 7 | karistos
# City not found. Skipping...
# Processing Record 34 of Set 7 | kroya
# Processing Record 35 of Set 7 | hobyo
# Processing Record 36 of Set 7 | ixtapa
# Processing Record 37 of Set 7 | coihaique
# Processing Record 38 of Set 7 | kumo
# Processing Record 39 of Set 7 | narovchat
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | boa vista
# Processing Record 42 of Set 7 | nioro
# Processing Record 43 of Set 7 | jieshi
# Processing Record 44 of Set 7 | coulihaut
# City not found. Skipping...
# Processing Record 45 of Set 7 | skibbereen
# Processing Record 46 of Set 7 | paamiut
# Processing Record 47 of Set 7 | alaca
# Processing Record 48 of Set 7 | torit
# Processing Record 49 of Set 7 | weligama
# Processing Record 50 of Set 7 | myitkyina
# Processing Record 1 of Set 8 | bene ayish
# Processing Record 2 of Set 8 | pecos
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 8 | duzce
# Processing Record 6 of Set 8 | shurob
# Processing Record 7 of Set 8 | ukiah
# Processing Record 8 of Set 8 | belyy yar
# Processing Record 9 of Set 8 | sao jose da coroa grande
# Processing Record 10 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 8 | mountain home
# Processing Record 13 of Set 8 | araouane
# Processing Record 14 of Set 8 | holland
# Processing Record 15 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 8 | concepcion del oro
# Processing Record 17 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 8 | beloha
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | ulladulla
# Processing Record 21 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 8 | cacador
# Processing Record 23 of Set 8 | provideniya
# Processing Record 24 of Set 8 | khani
# Processing Record 25 of Set 8 | taoudenni
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | kudahuvadhoo
# Processing Record 28 of Set 8 | miandrivazo
# Processing Record 29 of Set 8 | kahului
# Processing Record 30 of Set 8 | vitim
# Processing Record 31 of Set 8 | agirish
# Processing Record 32 of Set 8 | port hedland
# Processing Record 33 of Set 8 | cayenne
# Processing Record 34 of Set 8 | tir pol
# City not found. Skipping...
# Processing Record 35 of Set 8 | shache
# Processing Record 36 of Set 8 | saquena
# Processing Record 37 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 8 | batemans bay
# Processing Record 39 of Set 8 | zaysan
# Processing Record 40 of Set 8 | tautira
# Processing Record 41 of Set 8 | hirara
# Processing Record 42 of Set 8 | ambon
# Processing Record 43 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 8 | hovd
# Processing Record 45 of Set 8 | bayeux
# Processing Record 46 of Set 8 | ibimirim
# Processing Record 47 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 48 of Set 8 | olinda
# Processing Record 49 of Set 8 | geraldton
# Processing Record 50 of Set 8 | am timan
# Processing Record 1 of Set 9 | sembe
# Processing Record 2 of Set 9 | axim
# Processing Record 3 of Set 9 | thinadhoo
# Processing Record 4 of Set 9 | lavrentiya
# Processing Record 5 of Set 9 | san policarpo
# Processing Record 6 of Set 9 | shingu
# Processing Record 7 of Set 9 | mingyue
# Processing Record 8 of Set 9 | salalah
# Processing Record 9 of Set 9 | teknaf
# Processing Record 10 of Set 9 | oshikango
# Processing Record 11 of Set 9 | carballo
# Processing Record 12 of Set 9 | pontianak
# Processing Record 13 of Set 9 | rio grande
# Processing Record 14 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 9 | codrington
# Processing Record 16 of Set 9 | hearst
# Processing Record 17 of Set 9 | storforshei
# Processing Record 18 of Set 9 | kazachinskoye
# Processing Record 19 of Set 9 | jardim
# Processing Record 20 of Set 9 | amapa
# Processing Record 21 of Set 9 | eyl
# Processing Record 22 of Set 9 | buala
# Processing Record 23 of Set 9 | kouroussa
# Processing Record 24 of Set 9 | eenhana
# Processing Record 25 of Set 9 | northam
# Processing Record 26 of Set 9 | kiama
# Processing Record 27 of Set 9 | meulaboh
# Processing Record 28 of Set 9 | verkhnevilyuysk
# Processing Record 29 of Set 9 | necochea
# Processing Record 30 of Set 9 | los llanos de aridane
# Processing Record 31 of Set 9 | taksimo
# Processing Record 32 of Set 9 | shetpe
# Processing Record 33 of Set 9 | markova
# Processing Record 34 of Set 9 | anadyr
# Processing Record 35 of Set 9 | vanimo
# Processing Record 36 of Set 9 | festus
# Processing Record 37 of Set 9 | sri aman
# Processing Record 38 of Set 9 | girne
# Processing Record 39 of Set 9 | dhuburi
# Processing Record 40 of Set 9 | awjilah
# Processing Record 41 of Set 9 | ginir
# Processing Record 42 of Set 9 | huarmey
# Processing Record 43 of Set 9 | chauk
# Processing Record 44 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 9 | xinqing
# Processing Record 46 of Set 9 | varhaug
# Processing Record 47 of Set 9 | cam ranh
# Processing Record 48 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 9 | surgut
# Processing Record 50 of Set 9 | aasiaat
# Processing Record 1 of Set 10 | katha
# City not found. Skipping...
# Processing Record 2 of Set 10 | zelenets
# Processing Record 3 of Set 10 | gold coast
# Processing Record 4 of Set 10 | christchurch
# Processing Record 5 of Set 10 | raton
# Processing Record 6 of Set 10 | college
# Processing Record 7 of Set 10 | derzhavinsk
# Processing Record 8 of Set 10 | topolobampo
# Processing Record 9 of Set 10 | osakarovka
# Processing Record 10 of Set 10 | san carlos de bariloche
# Processing Record 11 of Set 10 | klaksvik
# Processing Record 12 of Set 10 | qazanbulaq
# Processing Record 13 of Set 10 | xinzhou
# Processing Record 14 of Set 10 | trincomalee
# Processing Record 15 of Set 10 | mana
# Processing Record 16 of Set 10 | kamenka
# Processing Record 17 of Set 10 | colares
# Processing Record 18 of Set 10 | ulcinj
# Processing Record 19 of Set 10 | linxia
# Processing Record 20 of Set 10 | vostok
# Processing Record 21 of Set 10 | san pedro de macoris
# Processing Record 22 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 10 | nowe miasto lubawskie
# Processing Record 24 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | kaili
# Processing Record 26 of Set 10 | parkes
# Processing Record 27 of Set 10 | saint-prosper
# Processing Record 28 of Set 10 | bengkulu
# Processing Record 29 of Set 10 | sai buri
# Processing Record 30 of Set 10 | bogorodskoye
# Processing Record 31 of Set 10 | gorin
# Processing Record 32 of Set 10 | phangnga
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | jasper
# Processing Record 35 of Set 10 | yangjiang
# Processing Record 36 of Set 10 | hwange
# Processing Record 37 of Set 10 | keetmanshoop
# Processing Record 38 of Set 10 | angoche
# Processing Record 39 of Set 10 | tevriz
# Processing Record 40 of Set 10 | fort nelson
# Processing Record 41 of Set 10 | saint-georges
# Processing Record 42 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 10 | tanete
# Processing Record 44 of Set 10 | dire
# Processing Record 45 of Set 10 | pyay
# Processing Record 46 of Set 10 | qandala
# Processing Record 47 of Set 10 | afogados da ingazeira
# Processing Record 48 of Set 10 | grindavik
# Processing Record 49 of Set 10 | laubach
# Processing Record 50 of Set 10 | barcelos
# Processing Record 1 of Set 11 | puerto baquerizo moreno
# Processing Record 2 of Set 11 | mitsamiouli
# Processing Record 3 of Set 11 | rawson
# Processing Record 4 of Set 11 | antofagasta
# Processing Record 5 of Set 11 | gayny
# Processing Record 6 of Set 11 | thanh hoa
# Processing Record 7 of Set 11 | tulum
# Processing Record 8 of Set 11 | grand haven
# Processing Record 9 of Set 11 | chiplun
# Processing Record 10 of Set 11 | minuri
# Processing Record 11 of Set 11 | aswan
# Processing Record 12 of Set 11 | longhua
# Processing Record 13 of Set 11 | xiuyan
# Processing Record 14 of Set 11 | richards bay
# Processing Record 15 of Set 11 | tonantins
# Processing Record 16 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 11 | sinnamary
# Processing Record 18 of Set 11 | bac lieu
# Processing Record 19 of Set 11 | bentiu
# Processing Record 20 of Set 11 | san isidro
# Processing Record 21 of Set 11 | phan thiet
# Processing Record 22 of Set 11 | bongandanga
# Processing Record 23 of Set 11 | pontal do parana
# Processing Record 24 of Set 11 | sola
# Processing Record 25 of Set 11 | caravelas
# Processing Record 26 of Set 11 | churapcha
# Processing Record 27 of Set 11 | kargasok
# Processing Record 28 of Set 11 | troitskoye
# Processing Record 29 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 11 | chabahar
# Processing Record 31 of Set 11 | fantanele
# Processing Record 32 of Set 11 | sault sainte marie
# Processing Record 33 of Set 11 | plettenberg bay
# Processing Record 34 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 11 | dicabisagan
# Processing Record 36 of Set 11 | waipawa
# Processing Record 37 of Set 11 | lunglei
# Processing Record 38 of Set 11 | okha
# Processing Record 39 of Set 11 | kuliyapitiya
# Processing Record 40 of Set 11 | vikravandi
# Processing Record 41 of Set 11 | mandalgovi
# Processing Record 42 of Set 11 | waddan
# Processing Record 43 of Set 11 | taltal
# Processing Record 44 of Set 11 | qui nhon
# Processing Record 45 of Set 11 | palmas
# Processing Record 46 of Set 11 | sapao
# City not found. Skipping...
# Processing Record 47 of Set 11 | sidney
# Processing Record 48 of Set 11 | kita
# Processing Record 49 of Set 11 | pangnirtung
# Processing Record 50 of Set 11 | coahuayana
# Processing Record 1 of Set 12 | loandjili
# Processing Record 2 of Set 12 | olafsvik
# Processing Record 3 of Set 12 | santa isabel do rio negro
# Processing Record 4 of Set 12 | lazaro cardenas
# Processing Record 5 of Set 12 | flinders
# Processing Record 6 of Set 12 | yulara
# Processing Record 7 of Set 12 | san luis
# Processing Record 8 of Set 12 | natal
# Processing Record 9 of Set 12 | homer
# Processing Record 10 of Set 12 | dawlatabad
# Processing Record 11 of Set 12 | viedma
# Processing Record 12 of Set 12 | gopalpur
# Processing Record 13 of Set 12 | sadao
# Processing Record 14 of Set 12 | huari
# Processing Record 15 of Set 12 | hue
# Processing Record 16 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 12 | luderitz
# Processing Record 18 of Set 12 | tiarei
# Processing Record 19 of Set 12 | lufilufi
# Processing Record 20 of Set 12 | ugoofaaru
# Processing Record 21 of Set 12 | kashi
# Processing Record 22 of Set 12 | maceio
# Processing Record 23 of Set 12 | matao
# Processing Record 24 of Set 12 | remedios
# Processing Record 25 of Set 12 | monterrey
# Processing Record 26 of Set 12 | sao joao da barra
# Processing Record 27 of Set 12 | saint-augustin
# Processing Record 28 of Set 12 | finnsnes
# Processing Record 29 of Set 12 | jensen beach
# Processing Record 30 of Set 12 | santa rosa
# Processing Record 31 of Set 12 | kurumkan
# Processing Record 32 of Set 12 | oranjemund
# Processing Record 33 of Set 12 | high level
# Processing Record 34 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 12 | elmira
# Processing Record 36 of Set 12 | komsomolskiy
# Processing Record 37 of Set 12 | vila franca do campo
# Processing Record 38 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 12 | miri
# Processing Record 40 of Set 12 | oksfjord
# Processing Record 41 of Set 12 | port augusta
# Processing Record 42 of Set 12 | gemena
# Processing Record 43 of Set 12 | cozumel
# Processing Record 44 of Set 12 | beaverlodge
# Processing Record 45 of Set 12 | grenada
# Processing Record 46 of Set 12 | yerbogachen
# Processing Record 47 of Set 12 | kasama
# Processing Record 48 of Set 12 | camapua
# Processing Record 49 of Set 12 | pasaje
# Processing Record 50 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 13 | lisala
# Processing Record 2 of Set 13 | rabo de peixe
# Processing Record 3 of Set 13 | uitenhage
# Processing Record 4 of Set 13 | nara
# Processing Record 5 of Set 13 | whitecourt
# Processing Record 6 of Set 13 | santa ana
# Processing Record 7 of Set 13 | abu dhabi
# Processing Record 8 of Set 13 | pimenta bueno
# Processing Record 9 of Set 13 | qobustan
# Processing Record 10 of Set 13 | mogadishu
# Processing Record 11 of Set 13 | tarko-sale
# Processing Record 12 of Set 13 | general pico
# Processing Record 13 of Set 13 | san lorenzo
# Processing Record 14 of Set 13 | annau
# Processing Record 15 of Set 13 | maragogi
# Processing Record 16 of Set 13 | altamont
# Processing Record 17 of Set 13 | luganville
# Processing Record 18 of Set 13 | bilma
# Processing Record 19 of Set 13 | mulege
# Processing Record 20 of Set 13 | prado
# Processing Record 21 of Set 13 | potosi
# Processing Record 22 of Set 13 | gamboma
# Processing Record 23 of Set 13 | bealanana
# Processing Record 24 of Set 13 | deputatskiy
# Processing Record 25 of Set 13 | bullhead city
# Processing Record 26 of Set 13 | alyangula
# Processing Record 27 of Set 13 | hualmay
# Processing Record 28 of Set 13 | pangody
# Processing Record 29 of Set 13 | adre
# Processing Record 30 of Set 13 | hudiksvall
# Processing Record 31 of Set 13 | ler
# Processing Record 32 of Set 13 | imbituba
# Processing Record 33 of Set 13 | huron
# Processing Record 34 of Set 13 | yar-sale
# Processing Record 35 of Set 13 | solnechnyy
# Processing Record 36 of Set 13 | antsohihy
# Processing Record 37 of Set 13 | butembo
# Processing Record 38 of Set 13 | asyut
# Processing Record 39 of Set 13 | porto novo
# Processing Record 40 of Set 13 | burnie
# Processing Record 41 of Set 13 | carnot
# Processing Record 42 of Set 13 | santa catarina de tepehuanes
# Processing Record 43 of Set 13 | korla
# Processing Record 44 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 45 of Set 13 | kapuskasing
# Processing Record 46 of Set 13 | olcea
# Processing Record 47 of Set 13 | haverhill
# Processing Record 48 of Set 13 | sobolevo
# Processing Record 49 of Set 13 | southbridge
# Processing Record 50 of Set 13 | umm kaddadah
# Processing Record 1 of Set 14 | raga
# Processing Record 2 of Set 14 | domoni
# Processing Record 3 of Set 14 | nyrob
# Processing Record 4 of Set 14 | san vicente
# Processing Record 5 of Set 14 | belebey
# Processing Record 6 of Set 14 | raudeberg
# Processing Record 7 of Set 14 | george town
# Processing Record 8 of Set 14 | port macquarie
# Processing Record 9 of Set 14 | nouakchott
# Processing Record 10 of Set 14 | kaeo
# Processing Record 11 of Set 14 | ranot
# Processing Record 12 of Set 14 | janoshaza
# Processing Record 13 of Set 14 | talcahuano
# Processing Record 14 of Set 14 | sambava
# Processing Record 15 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 16 of Set 14 | puerto rico
# Processing Record 17 of Set 14 | alegrete
# Processing Record 18 of Set 14 | sechelt
# Processing Record 19 of Set 14 | pocone
# Processing Record 20 of Set 14 | lata
# Processing Record 21 of Set 14 | kalabo
# Processing Record 22 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 14 | egvekinot
# Processing Record 24 of Set 14 | touba
# Processing Record 25 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 26 of Set 14 | rebrikha
# Processing Record 27 of Set 14 | troitsko-pechorsk
# Processing Record 28 of Set 14 | bud
# Processing Record 29 of Set 14 | myrtle beach
# Processing Record 30 of Set 14 | yantongshan
# Processing Record 31 of Set 14 | kiruna
# Processing Record 32 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 14 | kropotkin
# Processing Record 34 of Set 14 | matara
# Processing Record 35 of Set 14 | birecik
# Processing Record 36 of Set 14 | la victoria
# Processing Record 37 of Set 14 | odweyne
# Processing Record 38 of Set 14 | bemidji
# Processing Record 39 of Set 14 | dordrecht
# Processing Record 40 of Set 14 | kathu
# Processing Record 41 of Set 14 | kondopoga
# Processing Record 42 of Set 14 | farafangana
# Processing Record 43 of Set 14 | roebourne
# Processing Record 44 of Set 14 | atikokan
# Processing Record 45 of Set 14 | pundaguitan
# Processing Record 46 of Set 14 | port shepstone
# Processing Record 47 of Set 14 | amahai
# Processing Record 48 of Set 14 | manokwari
# Processing Record 49 of Set 14 | itacarambi
# Processing Record 50 of Set 14 | kashary
# Processing Record 1 of Set 15 | honningsvag
# Processing Record 2 of Set 15 | svetlaya
# Processing Record 3 of Set 15 | melong
# Processing Record 4 of Set 15 | villa vazquez
# City not found. Skipping...
# Processing Record 5 of Set 15 | yumen
# Processing Record 6 of Set 15 | manitouwadge
# Processing Record 7 of Set 15 | ust-ishim
# Processing Record 8 of Set 15 | zhangjiakou
# Processing Record 9 of Set 15 | gat
# Processing Record 10 of Set 15 | chenzhou
# Processing Record 11 of Set 15 | porbandar
# Processing Record 12 of Set 15 | sitka
# Processing Record 13 of Set 15 | chebsara
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | periyanegamam
# Processing Record 16 of Set 15 | kankaanpaa
# Processing Record 17 of Set 15 | conde
# Processing Record 18 of Set 15 | tupik
# Processing Record 19 of Set 15 | turukhansk
# Processing Record 20 of Set 15 | ostrogozhsk
# Processing Record 21 of Set 15 | tura
# Processing Record 22 of Set 15 | kidal
# Processing Record 23 of Set 15 | urucui
# Processing Record 24 of Set 15 | mayor pablo lagerenza
# Processing Record 25 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 15 | katunino
# Processing Record 27 of Set 15 | atar
# Processing Record 28 of Set 15 | bella union
# Processing Record 29 of Set 15 | tjome
# Processing Record 30 of Set 15 | salinopolis
# Processing Record 31 of Set 15 | chegdomyn
# Processing Record 32 of Set 15 | santa maria
# Processing Record 33 of Set 15 | okato
# Processing Record 34 of Set 15 | harlingen
# Processing Record 35 of Set 15 | pipraich
# Processing Record 36 of Set 15 | safaqis
# City not found. Skipping...
# Processing Record 37 of Set 15 | karratha
# Processing Record 38 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 39 of Set 15 | haines junction
# Processing Record 40 of Set 15 | guanica
# Processing Record 41 of Set 15 | carupano
# Processing Record 42 of Set 15 | sarny
# Processing Record 43 of Set 15 | sukumo
# Processing Record 44 of Set 15 | lasa
# Processing Record 45 of Set 15 | kuytun
# Processing Record 46 of Set 15 | vidalia
# Processing Record 47 of Set 15 | santa rosa del sur
# Processing Record 48 of Set 15 | vigrestad
# Processing Record 49 of Set 15 | saint anthony
# Processing Record 50 of Set 15 | yelizovo
# Processing Record 1 of Set 16 | marzuq
# Processing Record 2 of Set 16 | camacha
# Processing Record 3 of Set 16 | seoul
# Processing Record 4 of Set 16 | senanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Reorder the columns of the DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Vaini      TO -21.2000 -175.2000     80.60        65
# 1        Jacareacanga      BR  -6.2222  -57.7528     72.16        99
# 2            Cidreira      BR -30.1811  -50.2056     70.09        85
# 3              Jawhar      SO   2.7809   45.5005     79.29        74
# 4  Ribas Do Rio Pardo      BR -20.4431  -53.7592     72.86        67
# 5               Kapaa      US  22.0752 -159.3190     75.20        60
# 6           Bathsheba      BB  13.2167  -59.5167     78.80        65
# 7             Mataura      NZ -46.1927  168.8643     60.01        73
# 8          Nikolskoye      RU  59.7035   30.7861     44.60        42
# 9          Port Hardy      CA  50.6996 -127.4199     66.20        45
#
#    Cloudiness  Wind Speed Current Description
# 0          20        6.91          few clouds
# 1         100        1.92       moderate rain
# 2         100        7.72     overcast clouds
# 3          12        5.39          few clouds
# 4          51        4.83       broken clouds
# 5          40       12.66    scattered clouds
# 6          40       19.57    scattered clouds
# 7          70        7.00       broken clouds
# 8           0        8.95           clear sky
# 9           1        8.05           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
